# %%
from utils.Variable_setup import *
from utils.Extraction_functions import *
import pickle
import os
# Out:
# 200721-09:59:43,400 nipype.utils INFO:
# 	 Running nipype version 1.5.0-rc1 (latest: 1.5.0)

# %%
metrics = ['DKI_Thresholded',  'MAPMRI',  'NODDI']
submetrics = DKI_Metrics + MAPMRI_Metrics + NODDI_Metrics

# %% [markdown]
# ## Initialize nan filled arrays

# %%
import numpy as np
Extracted_Data = {}
Extracted_Data['Description'] = ' ##SAGAB## Dict containing ROI-Wise extracted values for Advanced Metrics'

for proc in preprocs:
    Extracted_Data[proc] = {}
    for met in metrics:
        Extracted_Data[proc][met] = {}
        for submet in submetrics:
            if not os.path.isdir(os.path.join(Advanced_maps_path,proc,met,submet)):
                continue
            else:
                Extracted_Data[proc][met][submet] = {}
                for ROI in ROIS:
                    Extracted_Data[proc][met][submet][ROI] = np.full([num_subjects, num_sessions], np.nan)

# %%
failed_files = []
for ROI in ROIS:
    fROI = os.path.join(ROIs_path,ROI)
    for proc in preprocs:
        for met in metrics:
            for submet in submetrics:
                
                #Save every submetric
                with open(os.path.join(data_path,'SAGAB_Advanced_Metric_ROIWISE_Extracted_Data.pckl'), 'wb') as handle:
                    pickle.dump(Extracted_Data, handle, protocol=pickle.HIGHEST_PROTOCOL)
                    
                if not os.path.isdir(os.path.join(Advanced_maps_path,proc,met,submet)):
                    continue
                else:
                    for s, ses in enumerate(sess):
                        fpath = os.path.join(Advanced_maps_path,proc,met,submet)                
                        for i in range(1,num_subjects+1):
                            substring = 'sub-'+str(i).zfill(2)+'_'+ses+'*'
                            file = find(substring, fpath)
                            if not file:
                                continue
                            else:
                                file = ''.join(file)
                                if os.path.isfile(os.path.join(os.getcwd(),'stat_result.json')):
                                    try:
                                        os.remove(os.path.join(os.getcwd(),'stat_result.json'))
                                    except:
                                        pass
                                try:
                                    Extracted_Data[proc][met][submet][ROI][i-1,s] = FSLROI_Image(file, fROI)
                                except:
                                    print('failed file: ', file)
                                    failed_files.append(file)
print('finished')
print('#############')
print(failed_files)
print('#############')
# Out:
# 200721-09:59:48,13 nipype.interface INFO:
# 	 stdout 2020-07-21T09:59:48.013440:1.207086
# 200721-09:59:51,892 nipype.interface INFO:
# 	 stdout 2020-07-21T09:59:51.892738:1.173599
# 200721-09:59:55,486 nipype.interface INFO:
# 	 stdout 2020-07-21T09:59:55.486174:1.164293
# 200721-09:59:59,110 nipype.interface INFO:
# 	 stdout 2020-07-21T09:59:59.110595:1.210668
# 200721-10:00:02,460 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:02.459936:1.098317
# 200721-10:00:05,778 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:05.778312:1.318552
# 200721-10:00:09,263 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:09.263548:1.109153
# 200721-10:00:12,545 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:12.545033:1.289734
# 200721-10:00:16,580 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:16.580691:1.235538
# 200721-10:00:20,55 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:20.055433:0.789179
# 200721-10:00:24,493 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:24.492754:1.282894
# 200721-10:00:28,9 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00:28.009638:1.124488
# 200721-10:00:30,962 nipype.interface INFO:
# 	 stdout 2020-07-21T10:00
nipype.interface INFO:
# 	 stdout 2020-07-21T10:11:56.646103:0.740861
# 200721-10:11:59,970 nipype.interface INFO:
# 	 stdout 2020-07-21T10:11:59.969942:1.010115
# 200721-10:12:03,331 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:03.331037:1.133546
# 200721-10:12:06,481 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:06.481002:0.945745
# 200721-10:12:10,36 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:10.036030:1.089933
# 200721-10:12:13,711 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:13.711476:1.065232
# 200721-10:12:16,887 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:16.886882:1.034315
# 200721-10:12:19,974 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:19.974185:1.029472
# 200721-10:12:23,189 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:23.189349:1.007441
# 200721-10:12:26,403 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:26.403044:0.819306
# 200721-10:12:29,704 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:29.703939:0.996564
# 200721-10:12:33,68 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:33.068340:0.852925
# 200721-10:12:36,393 nipype.interface INFO:
# 	 stdout 2020-07-21T10:12:36.392944:1.007807
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/SAGAB/utils/Extraction_functions.py in FSLROI_Image(Image, ROI)
#      13         by ROI."""
#      14     stats = ImageStats(in_file=Image, op_string='-k %s -m' %ROI)
# ---> 15     return(stats.aggregate_outputs().out_stat)
#      16
#      17 def find(pattern, path, fullpath=True):
#
# ~/anaconda3/lib/python3.7/site-packages/nipype/interfaces/fsl/utils.py in aggregate_outputs(self, runtime, needed_outputs)
#     815         if runtime is None:
#     816             try:
# --> 817                 out_stat = load_json(outfile)["stat"]
#     818             except IOError:
#     819                 return self.run().outputs
#
# ~/anaconda3/lib/python3.7/site-packages/nipype/utils/filemanip.py in load_json(filename)
#     591
#     592     with open(filename, "r") as fp:
# --> 593         data = json.load(fp)
#     594     return data
#     595
#
# ~/anaconda3/lib/python3.7/site-packages/simplejson/__init__.py in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, namedtuple_as_object, tuple_as_array, **kw)
#     469         parse_float=parse_float, parse_int=parse_int,
#     470         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 471         use_decimal=use_decimal, **kw)
#     472
#     473
#
# ~/anaconda3/lib/python3.7/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     523             parse_constant is None and object_pairs_hook is None
#     524             and not use_decimal and not kw):
# --> 525         return _default_decoder.decode(s)
#     526     if cls is None:
#     527         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, bytes):
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# ~/anaconda3/lib/python3.7/site-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## This will save a pickle

# %%
import pickle


with open(os.path.join(data_path,'SAGAB_Advanced_Metric_ROIWISE_Extracted_Data.pckl'), 'wb') as handle:
    pickle.dump(Extracted_Data, handle, protocol=pickle.HIGHEST_PROTOCOL)
